# %% [markdown]
# # TraceAI — AI Agent Analysis
# Rename `agent_analysis.py` → open as notebook in Jupyter, or copy cells from that file.
# All data is hypothetical — AlNakheel Trading Co.

# %%
# Run from the backend/ directory
# pip install -r requirements.txt  (first time only)
import sys
sys.path.insert(0, '..')

# Then paste the cells from agent_analysis.py
